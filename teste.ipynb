# %%
print("inicio do projeto de house pricing")
# Out:
# inicio do projeto de house pricing

# %%
conta = 0
for i in range(1000,9991):
    if i%10 ==0 and i%5==0 and i%7==0:
        conta = conta +1
        print(i)

# %%
teste = str(1636)
teste.count("6")
# Out:
# 2

# %%
teste = [str(i) for i in range(0,1537)]

# %%
soma = 0
for i in teste:
    seis = i.count("6")
    soma = soma + seis
soma
# Out:
# 404

# %%
100%6
# Out:
# 4
